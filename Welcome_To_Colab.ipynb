# %% [markdown]
# <a href="https://colab.research.google.com/github/Mani7527/python_bootcamp/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#min,max,sum,sorted
lst=[1,5374,4839,12902,104309,3884]
min(lst)
max(lst)

print(sorted(lst))
# Out:
# [1, 3884, 4839, 5374, 12902, 104309]

# %%
tp=(1,2,33,14)

# a=sorted(tp)
a=tuple(sorted(tp))

print(a)



#tuples function
#category             function
#count values         count()
#find                  index()
#size                  len()
#total                 sum()
#highrest/lowest       max()/min()
#sort                  sorted()(return list)
# Out:
# (1, 2, 14, 33)

# %%
lst=[1,56,423,48934,90]
