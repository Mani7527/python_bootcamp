# %% [markdown]
# <a href="https://colab.research.google.com/github/Mani7527/python_bootcamp/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
def add(a,b):
  print(a+b)
add(10,20)
# Out:
# 30

# %%
#lambda function

x=lambda a: 2*a
print(x(2))
# Out:
# 4

# %%
st=" "
print(len(st))

st="anand"
x=st.upper()
print(x)
# Out:
# 1
# ANAND

# %%
st="manikesh kumar"

print(len(st))
x=st.lower()
print(x)

y=st.upper()
print(y)

z=st.title()
print(z)

a=st.capitalize()
print(a)
# Out:
# 14
# manikesh kumar
# MANIKESH KUMAR
# Manikesh Kumar
# Manikesh kumar

# %%
st1="Manikesh Kumar"
#strip to remove the space from front and back

x=st1.strip()
print(x)
# Out:
# Manikesh Kumar

# %%
first_name=" Manikesh "
last_name=" kumar "

first_name=first_name.strip()
last_name=last_name.strip()

print(first_name+' '+last_name)
# Out:
# Manikesh kumar

# %%
a="today"
b="   weather "
c="is Good"

c=c.lower()
b=b.strip()
a=a.title()

print(a+','+b+' '+c+'.')
# Out:
# Today,weather is good.

# %%
m="Manikesh"
b="kumar"
b=b.replace("kumar","mani")
print(b)
# Out:
# mani

# %%
m="My name is khan"
m.find("name")
m.index("y")

#find(): if the word or letter is found at any index then return the index number else it will return -1
#index(): if any word or letter is found then it will return the index else it will throw error if not found
# Out:
# 1

# %%
s="hello world"
print(s[-2])
print(s[-5])
# Out:
# l
# w

# %%
s="hello coder"
print(s[1:3])#from index 1 to 2 exlude the 3 element
print(s[6:])#from 6 to last
print(s[:5]) #it will print till the 4 index
# Out:
# el
# coder
# hello

# %%
st={2,2,23,2,1}
print(st)
st1={4,7,1,2,89,90283,0,121221,32}
print(st1)
print(sorted(st1))
# Out:
# {1, 2, 23}
# {0, 1, 2, 32, 4, 121221, 7, 90283, 89}
# [0, 1, 2, 4, 7, 32, 89, 90283, 121221]

# %%
dct={
    "name":["manikesh","gattu","kiran","druv"],
    "age":"20",
    "occupation":"student",
    "class":"alpha",
    "roll_no":10,



}
print(dct)
print(dct['name'][0])
print(dct['name'])

dct['id']=12 #assigning a new value to the dct
print(dct)

del dct['name']
print(dct)
# Out:
# {'name': ['manikesh', 'gattu', 'kiran', 'druv'], 'age': '20', 'occupation': 'student', 'class': 'alpha', 'roll_no': 10}
# manikesh
# ['manikesh', 'gattu', 'kiran', 'druv']
# {'name': ['manikesh', 'gattu', 'kiran', 'druv'], 'age': '20', 'occupation': 'student', 'class': 'alpha', 'roll_no': 10, 'id': 12}
# {'age': '20', 'occupation': 'student', 'class': 'alpha', 'roll_no': 10, 'id': 12}
