# %% [markdown]
# <a href="https://colab.research.google.com/github/Mani7527/python_bootcamp/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst11=[2,4,2,0,9]
lst22=[1,8,7,2,0]

result=[]
for i in range(5):
  result.append(lst11[i]+lst22[i])
print (result)
# Out:
# [3, 12, 9, 2, 9]

# %%
a1=[]
a2=[]
size=int(input())

for i in range(size):
  x=int(input())
  a1.append(x)
for i in range(size):
  y=int(input())
  a2.append(y)

a3=[]
for i in range(size):
  a3.append(a1[i]+a2[i])
print(a3)
# Out:
# 5
# 1
# 2
# 3
# 4
# 5
# 9
# 8
# 7
# 6
# 5
# [10, 10, 10, 10, 10]
